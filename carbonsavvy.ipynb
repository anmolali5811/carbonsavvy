# %%
import pandas as pd

carbon_emission = pd.read_csv('data.csv')
carbon_emission
# Out:
#         Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 0    0.00632      18.0   2.31        0       0.538       6.575       65.2
# 1    0.02731       0.0   7.07        0       0.469       6.421       78.9
# 2    0.02729       0.0   7.07        0       0.469       7.185       61.1
# 3    0.03237       0.0   2.18        0       0.458       6.998       45.8
# 4    0.06905       0.0   2.18        0       0.458       7.147       54.2
# ..       ...       ...    ...      ...         ...         ...        ...
# 501  0.06263       0.0  11.93        0       0.573       6.593       69.1
# 502  0.04527       0.0  11.93        0       0.573       6.120       76.7
# 503  0.06076       0.0  11.93        0       0.573       6.976       91.0
# 504  0.10959       0.0  11.93        0       0.573       6.794       89.3
# 505  0.04741       0.0  11.93        0       0.573       6.030       80.8
#
#      Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear  \
# 0        4.0900          1       296     15.3     396.90     4.98
# 1        4.9671          2       242     17.8     396.90     9.14
# 2        4.9671          2       242     17.8     392.83     4.03
# 3        6.0622          3       222     18.7     394.63     2.94
# 4        6.0622          3       222     18.7     396.90     5.33
# ..          ...        ...       ...      ...        ...      ...
# 501      2.4786          1       273     21.0     391.99     9.67
# 502      2.2875          1       273     21.0     396.90     9.08
# 503      2.1675          1       273     21.0     396.90     5.64
# 504      2.3889          1       273     21.0     393.45     6.48
# 505      2.5050          1       273     21.0     396.90     7.88
#
#      CO2_Emission
# 0            24.0
# 1            21.6
# 2            34.7
# 3            33.4
# 4            36.2
# ..            ...
# 501          22.4
# 502          20.6
# 503          23.9
# 504          22.0
# 505          11.9
#
# [506 rows x 14 columns]

# %%
carbon_emission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Wind          506 non-null    float64
#  1   Vehicles      506 non-null    float64
#  2   Solar         506 non-null    float64
#  3   Garbage       506 non-null    int64
#  4   EVechicles    506 non-null    float64
#  5   Industries    501 non-null    float64
#  6   Foresting     506 non-null    float64
#  7   Population    506 non-null    float64
#  8   BioEnergy     506 non-null    int64
#  9   Recyling      506 non-null    int64
#  10  Thermal       506 non-null    float64
#  11  Buildings     506 non-null    float64
#  12  Nuclear       506 non-null    float64
#  13  CO2_Emission  506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
carbon_emission['Foresting'].value_counts()
# Out:
# 100.0    43
# 95.4      4
# 96.0      4
# 98.2      4
# 97.9      4
#          ..
# 58.4      1
# 74.4      1
# 73.4      1
# 33.1      1
# 89.3      1
# Name: Foresting, Length: 356, dtype: int64

# %%
carbon_emission.describe()
# Out:
#              Wind    Vehicles       Solar     Garbage  EVechicles  Industries  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284289
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705443
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#         Foresting  Population   BioEnergy    Recyling     Thermal   Buildings  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#           Nuclear  CO2_Emission
# count  506.000000    506.000000
# mean    12.653063     22.532806
# std      7.141062      9.197104
# min      1.730000      5.000000
# 25%      6.950000     17.025000
# 50%     11.360000     21.200000
# 75%     16.955000     25.000000
# max     37.970000     50.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
carbon_emission.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Wind'}>,
#         <Axes: title={'center': 'Vehicles'}>,
#         <Axes: title={'center': 'Solar'}>,
#         <Axes: title={'center': 'Garbage'}>],
#        [<Axes: title={'center': 'EVechicles'}>,
#         <Axes: title={'center': 'Industries'}>,
#         <Axes: title={'center': 'Foresting'}>,
#         <Axes: title={'center': 'Population'}>],
#        [<Axes: title={'center': 'BioEnergy'}>,
#         <Axes: title={'center': 'Recyling'}>,
#         <Axes: title={'center': 'Thermal'}>,
#         <Axes: title={'center': 'Buildings'}>],
#        [<Axes: title={'center': 'Nuclear'}>,
#         <Axes: title={'center': 'CO2_Emission'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # Co-relation Cofficient

# %%
corr_matrix = carbon_emission.corr()
corr_matrix['CO2_Emission'].sort_values(ascending=False)
# Out:
# CO2_Emission    1.000000
# Industries      0.695553
# Vehicles        0.360445
# Buildings       0.333461
# Population      0.249929
# Garbage         0.175260
# Foresting      -0.376955
# BioEnergy      -0.381626
# Wind           -0.388305
# EVechicles     -0.427321
# Recyling       -0.468536
# Solar          -0.483725
# Thermal        -0.507787
# Nuclear        -0.737663
# Name: CO2_Emission, dtype: float64

# %% [markdown]
# # Plotting Co-relations graph

# %%
carbon_emission.plot(kind='scatter',x='Vehicles',y="CO2_Emission",alpha=0.8)
# Out:
# <Axes: xlabel='Vehicles', ylabel='CO2_Emission'>

# %%
carbon_emission.plot(kind='scatter',x='Industries',y="CO2_Emission",alpha=0.8)
# Out:
# <Axes: xlabel='Industries', ylabel='CO2_Emission'>

# %%
carbon_emission.head()
# Out:
#       Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 0  0.00632      18.0   2.31        0       0.538       6.575       65.2
# 1  0.02731       0.0   7.07        0       0.469       6.421       78.9
# 2  0.02729       0.0   7.07        0       0.469       7.185       61.1
# 3  0.03237       0.0   2.18        0       0.458       6.998       45.8
# 4  0.06905       0.0   2.18        0       0.458       7.147       54.2
#
#    Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear  CO2_Emission
# 0      4.0900          1       296     15.3     396.90     4.98          24.0
# 1      4.9671          2       242     17.8     396.90     9.14          21.6
# 2      4.9671          2       242     17.8     392.83     4.03          34.7
# 3      6.0622          3       222     18.7     394.63     2.94          33.4
# 4      6.0622          3       222     18.7     396.90     5.33          36.2

# %% [markdown]
# # Combining The Attributes

# %%
carbon_emission['Nuclear_Solar'] = carbon_emission['Nuclear']+carbon_emission['Solar']

# %%
carbon_emission.head()
# Out:
#       Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 0  0.00632      18.0   2.31        0       0.538       6.575       65.2
# 1  0.02731       0.0   7.07        0       0.469       6.421       78.9
# 2  0.02729       0.0   7.07        0       0.469       7.185       61.1
# 3  0.03237       0.0   2.18        0       0.458       6.998       45.8
# 4  0.06905       0.0   2.18        0       0.458       7.147       54.2
#
#    Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear  CO2_Emission  \
# 0      4.0900          1       296     15.3     396.90     4.98          24.0
# 1      4.9671          2       242     17.8     396.90     9.14          21.6
# 2      4.9671          2       242     17.8     392.83     4.03          34.7
# 3      6.0622          3       222     18.7     394.63     2.94          33.4
# 4      6.0622          3       222     18.7     396.90     5.33          36.2
#
#    Nuclear_Solar
# 0           7.29
# 1          16.21
# 2          11.10
# 3           5.12
# 4           7.51

# %%
carbon_emission.plot(kind='scatter',x='Nuclear_Solar',y="CO2_Emission",alpha=0.8)
# Out:
# <Axes: xlabel='Nuclear_Solar', ylabel='CO2_Emission'>

# %%
corr_matrix = carbon_emission.corr()
corr_matrix['CO2_Emission'].sort_values(ascending=False)
# Out:
# CO2_Emission     1.000000
# Industries       0.695553
# Vehicles         0.360445
# Buildings        0.333461
# Population       0.249929
# Garbage          0.175260
# Foresting       -0.376955
# BioEnergy       -0.381626
# Wind            -0.388305
# EVechicles      -0.427321
# Recyling        -0.468536
# Solar           -0.483725
# Thermal         -0.507787
# Nuclear_Solar   -0.684776
# Nuclear         -0.737663
# Name: CO2_Emission, dtype: float64

# %%
from sklearn.model_selection import train_test_split
train_set,test_set = train_test_split(carbon_emission,test_size=0.2,random_state=42)
print(f"Rows in train set: {len(train_set)}\n Rows in test set: {len(test_set)}")
# Out:
# Rows in train set: 404
#  Rows in test set: 102

# %% [markdown]
# ## Perforoming Stratify Sampling on Data

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(carbon_emission,carbon_emission['Garbage']):
    stratify_train_set = carbon_emission.loc[train_index]
    stratify_test_set = carbon_emission.loc[test_index]

# %%
stratify_test_set['Garbage'].value_counts()
# Out:
# 0    95
# 1     7
# Name: Garbage, dtype: int64

# %%
stratify_train_set['Garbage'].value_counts()
# Out:
# 0    376
# 1     28
# Name: Garbage, dtype: int64

# %% [markdown]
# ## Hiding the Testing Data from the Models

# %%
carbon_emission = stratify_train_set.copy()
carbon_emission.describe()
# Out:
#              Wind    Vehicles       Solar     Garbage  EVechicles  Industries  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278630
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.715879
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.877250
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#         Foresting  Population   BioEnergy    Recyling     Thermal   Buildings  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#           Nuclear  CO2_Emission  Nuclear_Solar
# count  404.000000    404.000000     404.000000
# mean    12.791609     22.509406      24.136559
# std      7.235740      9.385531      12.668117
# min      1.730000      5.000000       4.370000
# 25%      6.847500     16.600000      13.427500
# 50%     11.570000     21.150000      21.965000
# 75%     17.102500     25.000000      34.577500
# max     36.980000     50.000000      57.420000

# %% [markdown]
# ## Handling Missing Values

# %%
co2_factors = stratify_train_set.drop("CO2_Emission",axis=1)
co2_factors = co2_factors.drop("Nuclear_Solar",axis=1)
co2_emission_labels = stratify_train_set["CO2_Emission"].copy()
co2_factors.head()
# Out:
#         Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 254  0.04819      80.0   3.64        0       0.392       6.108       32.0
# 348  0.01501      80.0   2.01        0       0.435       6.635       29.7
# 476  4.87141       0.0  18.10        0       0.614       6.484       93.6
# 321  0.18159       0.0   7.38        0       0.493       6.376       54.3
# 326  0.30347       0.0   7.38        0       0.493       6.312       28.9
#
#      Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear
# 254      9.2203          1       315     16.4     392.89     6.57
# 348      8.3440          4       280     17.0     390.94     5.99
# 476      2.3053         24       666     20.2     396.21    18.68
# 321      4.5404          5       287     19.6     396.90     6.87
# 326      5.4159          5       287     19.6     396.90     6.15

# %%
co2_emission_labels.head()
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: CO2_Emission, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(co2_factors)
co2_factors.describe()
# Out:
#              Wind    Vehicles       Solar     Garbage  EVechicles  Industries  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278630
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.715879
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.877250
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#         Foresting  Population   BioEnergy    Recyling     Thermal   Buildings  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#           Nuclear
# count  404.000000
# mean    12.791609
# std      7.235740
# min      1.730000
# 25%      6.847500
# 50%     11.570000
# 75%     17.102500
# max     36.980000

# %%
x = imputer.transform(co2_factors)
carbon_emission_tr = pd.DataFrame(x,columns = co2_factors.columns)

# %%
carbon_emission_tr.describe()
# Out:
#              Wind    Vehicles       Solar     Garbage  EVechicles  Industries  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.277941
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712351
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#         Foresting  Population   BioEnergy    Recyling     Thermal   Buildings  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#           Nuclear
# count  404.000000
# mean    12.791609
# std      7.235740
# min      1.730000
# 25%      6.847500
# 50%     11.570000
# 75%     17.102500
# max     36.980000

# %% [markdown]
# ## Creating Pipeline for new data

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])
carbon_emission_tr = my_pipeline.fit_transform(co2_factors)

# %% [markdown]
# ## Selecting Model for the "CarbonSavvy"

# %% [markdown]
# ### Training with Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(carbon_emission_tr,co2_emission_labels)
# Out:
# LinearRegression()

# %%
some_data = co2_factors.iloc[:5]
some_labels = co2_emission_labels.iloc[:5]
prepared_data = my_pipeline.transform(some_data)
model.predict(prepared_data)
# Out:
# array([23.94326142, 27.21037189, 20.58679373, 25.05300276, 23.76619521])

# %% [markdown]
# ## Evaluating the Model

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
co2_predictions = model.predict(carbon_emission_tr)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,carbon_emission_tr,co2_emission_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)
def print_scores(scores):
    print("Scores are: ",scores)
    print("Square root Mean error: ",scores.mean())
    print("std_deviation: ",scores.std())
print_scores(rmse_scores)
# Out:
# Scores are:  [4.22573544 4.26284616 5.09465418 3.82718288 5.33062627 4.38138142
#  7.47373273 5.47648757 4.1553652  6.06383181]
# Square root Mean error:  5.029184365050043
# std_deviation:  1.058412315043304

# %% [markdown]
# ## Training with Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
model = DecisionTreeRegressor()
model.fit(carbon_emission_tr,co2_emission_labels)
co2_emission_predictions = model.predict(carbon_emission_tr)
mse = mean_squared_error(co2_emission_labels,co2_emission_predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.0

# %% [markdown]
# ## Using Cross Validation Technique (KFold group data points)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,carbon_emission_tr,co2_emission_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([4.23034912, 5.67244086, 5.07559921, 3.90128184, 4.24399576,
#        3.00886191, 5.13590304, 3.91825854, 3.39035396, 3.64599095])

# %%
print_scores(rmse_scores)
# Out:
# Scores are:  [4.23034912 5.67244086 5.07559921 3.90128184 4.24399576 3.00886191
#  5.13590304 3.91825854 3.39035396 3.64599095]
# Square root Mean error:  4.222303519184524
# std_deviation:  0.7973974078389765

# %% [markdown]
# ## Training The model with Random forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np
model = RandomForestRegressor()
model.fit(carbon_emission_tr,co2_emission_labels)
housing_predictions = model.predict(carbon_emission_tr)
scores = cross_val_score(model,carbon_emission_tr,co2_emission_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)
print_scores(rmse_scores)
# Out:
# Scores are:  [2.72110755 2.93953829 4.5149679  2.76366934 3.44039688 2.64237218
#  4.99937827 3.40512201 3.05434874 3.35475707]
# Square root Mean error:  3.3835658242783078
# std_deviation:  0.7465574241764208

# %%
stratify_test_set = stratify_test_set.drop("Nuclear_Solar",axis=1)

# %% [markdown]
# ## Final Model Testing on the testing Dataset

# %%
x_test = stratify_test_set.drop("CO2_Emission",axis=1)
y_test = stratify_test_set["CO2_Emission"].copy()
x_test_prepared = my_pipeline.transform(x_test)
final_predictions = model.predict(x_test_prepared)
final_mse = mean_squared_error(y_test,final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 3.0077771741623027

# %%
print(final_predictions,list(y_test))
# Out:
# [25.056 11.635 25.742 21.683 19.444 14.626 20.063 14.467 32.19  41.628
#  19.812 12.427 23.995 30.573 19.543 11.26  31.652 14.124 23.705 18.903
#  19.857 17.776 20.92  22.143 18.263 30.734 16.041 32.674  8.914 33.787
#  22.301 21.439 23.483 11.292 20.795 11.274 43.395 24.533 23.142 42.717
#  23.692 30.662 20.451 20.757 18.931 33.434 45.273 20.15  20.176 21.953
#  21.794 14.827 21.34  15.255 24.884 32.966 42.264 29.085 18.994 20.874
#  47.559  9.053 18.989 25.508 14.621 33.624 19.813 17.637 19.094 33.96
#  26.783 22.851 21.429 22.297 34.73  12.636 15.897 19.905 20.561 21.207
#  22.717 20.997 13.825 22.76  20.393 21.328 13.852 21.71  21.537 23.335
#  19.024 26.882  7.219 26.661 19.093 29.592 19.992 31.294 14.527 25.995
#  21.684 19.867] [16.5, 10.2, 30.1, 23.0, 14.4, 15.6, 19.4, 14.1, 30.3, 35.2, 23.1, 13.8, 25.0, 27.9, 19.5, 12.3, 32.2, 13.5, 23.8, 21.7, 19.2, 19.5, 10.4, 23.2, 18.6, 28.5, 15.2, 32.0, 7.2, 34.6, 20.1, 20.6, 23.6, 13.1, 23.8, 12.7, 43.1, 24.7, 22.2, 44.0, 28.1, 31.0, 21.7, 23.4, 19.5, 33.1, 41.7, 18.7, 19.9, 20.6, 21.2, 13.6, 20.3, 17.8, 27.1, 31.5, 50.0, 29.1, 18.9, 20.4, 50.0, 7.2, 17.2, 36.2, 14.6, 33.2, 23.8, 19.9, 21.5, 37.3, 27.0, 22.0, 24.3, 19.8, 33.3, 7.0, 19.4, 20.9, 21.1, 20.4, 22.2, 11.9, 11.7, 21.6, 19.7, 23.0, 16.7, 21.7, 20.6, 23.3, 19.6, 28.0, 5.0, 24.4, 20.8, 24.8, 21.8, 23.6, 19.0, 25.0, 20.3, 21.5]

# %%
some_data = co2_factors.iloc[:1]
some_data
# Out:
#         Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 254  0.04819      80.0   3.64        0       0.392       6.108       32.0
#
#      Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear
# 254      9.2203          1       315     16.4     392.89     6.57

# %%
np.array(some_data)
# Out:
# array([[4.8190e-02, 8.0000e+01, 3.6400e+00, 0.0000e+00, 3.9200e-01,
#         6.1080e+00, 3.2000e+01, 9.2203e+00, 1.0000e+00, 3.1500e+02,
#         1.6400e+01, 3.9289e+02, 6.5700e+00]])

# %%
prepared_data = my_pipeline.transform(some_data)
prepared_data
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#         -0.23885882, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#         -0.97491834,  0.41164221, -0.86091034]])

# %%
model.predict(prepared_data)
# Out:
# array([22.511])

# %%
carbon_emission.head()
# Out:
#         Wind  Vehicles  Solar  Garbage  EVechicles  Industries  Foresting  \
# 254  0.04819      80.0   3.64        0       0.392       6.108       32.0
# 348  0.01501      80.0   2.01        0       0.435       6.635       29.7
# 476  4.87141       0.0  18.10        0       0.614       6.484       93.6
# 321  0.18159       0.0   7.38        0       0.493       6.376       54.3
# 326  0.30347       0.0   7.38        0       0.493       6.312       28.9
#
#      Population  BioEnergy  Recyling  Thermal  Buildings  Nuclear  \
# 254      9.2203          1       315     16.4     392.89     6.57
# 348      8.3440          4       280     17.0     390.94     5.99
# 476      2.3053         24       666     20.2     396.21    18.68
# 321      4.5404          5       287     19.6     396.90     6.87
# 326      5.4159          5       287     19.6     396.90     6.15
#
#      CO2_Emission  Nuclear_Solar
# 254          21.9          10.21
# 348          24.5           8.00
# 476          16.7          36.78
# 321          23.1          14.25
# 326          23.0          13.53

# %%
import pickle
pickle.dump(model,open('carbonSavvy.pkl','wb'))
